# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
path="/content/drive/MyDrive/data sets/matches.csv"
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
df.shape
# Out:
# (636, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
df['result'].value_counts().plot(kind='bar')

# %%
df['dl_applied'].value_counts().plot(kind='bar')

# %%
df['team1'].value_counts()
# Out:
# Mumbai Indians                 82
# Kings XI Punjab                77
# Chennai Super Kings            77
# Royal Challengers Bangalore    70
# Kolkata Knight Riders          68
# Delhi Daredevils               63
# Rajasthan Royals               54
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  14
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team1, dtype: int64

# %%
df.drop(columns=['dl_applied'],inplace=True)

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
df['winner'].value_counts().plot(kind='bar')

# %%
df['toss_decision'].value_counts().plot(kind='bar')

# %%
df['toss_decision'].value_counts()
# Out:
# field    363
# bat      273
# Name: toss_decision, dtype: int64

# %%
def toss_changer(text):
  if text == 'bat':
    return 1
  if text == 'field':
    return 0

# %%
df['t_decision 1-bat 0-field']=df['toss_decision']

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
df['t_decision 1-bat 0-field']=df['t_decision 1-bat 0-field'].apply(toss_changer)

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result                       winner  win_by_runs  win_by_wickets  \
# ...

# %%
df.drop(columns=['toss_decision'],inplace=True)

# %%
sns.barplot(x=df['t_decision 1-bat 0-field'],y=df['city']=='Pune')

# %%
df2= df[['team1','team2','winner']]

# %%
df2
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df2 = df2[df2['team1']=='Mumbai Indians']

# %%
df2
# Out:
#               team1                   team2                  winner
# 1    Mumbai Indians  Rising Pune Supergiant  Rising Pune Supergiant
# 23   Mumbai Indians        Delhi Daredevils          Mumbai Indians
# 43   Mumbai Indians        Delhi Daredevils          Mumbai Indians
# 46   Mumbai Indians     Sunrisers Hyderabad     Sunrisers Hyderabad
# 52   Mumbai Indians   Kolkata Knight Riders          Mumbai Indians
# ..              ...                     ...                     ...
# 587  Mumbai Indians     Sunrisers Hyderabad     Sunrisers Hyderabad
# 596  Mumbai Indians         Kings XI Punjab          Mumbai Indians
# 618  Mumbai Indians         Kings XI Punjab         Kings XI Punjab
# 622  Mumbai Indians        Delhi Daredevils          Mumbai Indians
# 629  Mumbai Indians           Gujarat Lions           Gujarat Lions
#
# [82 rows x 3 columns]

# %%
df2['team2'].value_counts()
# Out:
# Delhi Daredevils               15
# Chennai Super Kings            12
# Royal Challengers Bangalore    11
# Rajasthan Royals               10
# Kolkata Knight Riders           9
# Kings XI Punjab                 7
# Deccan Chargers                 5
# Sunrisers Hyderabad             4
# Pune Warriors                   3
# Rising Pune Supergiant          2
# Gujarat Lions                   2
# Kochi Tuskers Kerala            1
# Rising Pune Supergiants         1
# Name: team2, dtype: int64

# %%
df2 = df2[df2['team2']=='Chennai Super Kings']

# %%
df2
# Out:
#               team1                team2               winner
# 117  Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 161  Mumbai Indians  Chennai Super Kings  Chennai Super Kings
# 256  Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 385  Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 429  Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 456  Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 469  Mumbai Indians  Chennai Super Kings  Chennai Super Kings
# 489  Mumbai Indians  Chennai Super Kings  Chennai Super Kings
# 514  Mumbai Indians  Chennai Super Kings  Chennai Super Kings
# 529  Mumbai Indians  Chennai Super Kings  Chennai Super Kings
# 572  Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 575  Mumbai Indians  Chennai Super Kings       Mumbai Indians

# %%
df2['winner'].value_counts().plot(kind='bar')

# %%
df3= df[['team1','team2','winner']]

# %%
df3 = df3[df3['team1']=='Chennai Super Kings']
df3
# Out:
#                    team1                        team2               winner
# 60   Chennai Super Kings              Kings XI Punjab  Chennai Super Kings
# 66   Chennai Super Kings               Mumbai Indians  Chennai Super Kings
# 73   Chennai Super Kings  Royal Challengers Bangalore  Chennai Super Kings
# 78   Chennai Super Kings             Delhi Daredevils     Delhi Daredevils
# 82   Chennai Super Kings             Rajasthan Royals     Rajasthan Royals
# ..                   ...                          ...                  ...
# 546  Chennai Super Kings        Kolkata Knight Riders  Chennai Super Kings
# 553  Chennai Super Kings  Royal Challengers Bangalore  Chennai Super Kings
# 558  Chennai Super Kings               Mumbai Indians       Mumbai Indians
# 562  Chennai Super Kings             Rajasthan Royals  Chennai Super Kings
# 564  Chennai Super Kings             Delhi Daredevils     Delhi Daredevils
#
# [77 rows x 3 columns]

# %%
df3 = df3[df3['team2']=='Mumbai Indians']

# %%
df3
# Out:
#                    team1           team2               winner
# 66   Chennai Super Kings  Mumbai Indians  Chennai Super Kings
# 95   Chennai Super Kings  Mumbai Indians       Mumbai Indians
# 193  Chennai Super Kings  Mumbai Indians       Mumbai Indians
# 210  Chennai Super Kings  Mumbai Indians  Chennai Super Kings
# 233  Chennai Super Kings  Mumbai Indians  Chennai Super Kings
# 307  Chennai Super Kings  Mumbai Indians       Mumbai Indians
# 354  Chennai Super Kings  Mumbai Indians       Mumbai Indians
# 378  Chennai Super Kings  Mumbai Indians  Chennai Super Kings
# 453  Chennai Super Kings  Mumbai Indians  Chennai Super Kings
# 558  Chennai Super Kings  Mumbai Indians       Mumbai Indians

# %%
df3['winner'].value_counts().plot(kind='bar')

# %%
frames=[df2,df3]
df4= pd.concat(frames)
df4
# Out:
#                    team1                team2               winner
# 117       Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 161       Mumbai Indians  Chennai Super Kings  Chennai Super Kings
# 256       Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 385       Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 429       Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 456       Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 469       Mumbai Indians  Chennai Super Kings  Chennai Super Kings
# 489       Mumbai Indians  Chennai Super Kings  Chennai Super Kings
# 514       Mumbai Indians  Chennai Super Kings  Chennai Super Kings
# 529       Mumbai Indians  Chennai Super Kings  Chennai Super Kings
# 572       Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 575       Mumbai Indians  Chennai Super Kings       Mumbai Indians
# 66   Chennai Super Kings       Mumbai Indians  Chennai Super Kings
# ...

# %%
df4['winner'].value_counts().plot(kind='bar')

# %%
df.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner  result  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore  normal
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore  normal
# 633        Kolkata Knight Riders        Kolkata Knight Riders  normal
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad  normal
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad  normal
#
#                           winner  win_by_runs  win_by_wickets player_of_match  \
# 631  Royal Challengers Bangalore            0               6         V Kohli
# ...

# %%
df.sample(10)
# Out:
#       id  season        city        date                   team1  \
# 12    13    2017      Rajkot  2017-04-14  Rising Pune Supergiant
# 222  223    2010      Jaipur  2010-04-14        Rajasthan Royals
# 209  210    2010      Nagpur  2010-04-05        Rajasthan Royals
# 30    31    2017     Kolkata  2017-04-28        Delhi Daredevils
# 408  409    2013  Chandigarh  2013-04-21           Pune Warriors
# 460  461    2014   Abu Dhabi  2014-04-18     Sunrisers Hyderabad
# 519  520    2015        Pune  2015-04-10        Rajasthan Royals
# 360  361    2012      Jaipur  2012-05-10        Rajasthan Royals
# 298  299    2011      Mumbai  2011-05-20          Mumbai Indians
# 273  274    2011       Delhi  2011-05-02        Delhi Daredevils
#
#                            team2            toss_winner  result  \
# 12                 Gujarat Lions          Gujarat Lions  normal
# 222  Royal Challengers Bangalore       Rajasthan Royals  normal
# ...

# %%
df.corr()
# Out:
#                                 id    season  win_by_runs  win_by_wickets  \
# id                        1.000000  0.471087    -0.010263       -0.015510
# season                    0.471087  1.000000    -0.016815       -0.000708
# win_by_runs              -0.010263 -0.016815     1.000000       -0.565181
# win_by_wickets           -0.015510 -0.000708    -0.565181        1.000000
# umpire3                        NaN       NaN          NaN             NaN
# t_decision 1-bat 0-field -0.055410 -0.216592    -0.020516       -0.001609
#
#                           umpire3  t_decision 1-bat 0-field
# id                            NaN                 -0.055410
# season                        NaN                 -0.216592
# win_by_runs                   NaN                 -0.020516
# win_by_wickets                NaN                 -0.001609
# umpire3                       NaN                       NaN
# t_decision 1-bat 0-field      NaN                  1.000000

# %%
# calculating mumbai win percentage in their home-ground
d2=df[['city','winner','team1','team2']]

# %%
d2
# Out:
#           city                       winner                        team1  \
# 0    Hyderabad          Sunrisers Hyderabad          Sunrisers Hyderabad
# 1         Pune       Rising Pune Supergiant               Mumbai Indians
# 2       Rajkot        Kolkata Knight Riders                Gujarat Lions
# 3       Indore              Kings XI Punjab       Rising Pune Supergiant
# 4    Bangalore  Royal Challengers Bangalore  Royal Challengers Bangalore
# ..         ...                          ...                          ...
# 631     Raipur  Royal Challengers Bangalore             Delhi Daredevils
# 632  Bangalore  Royal Challengers Bangalore                Gujarat Lions
# 633      Delhi          Sunrisers Hyderabad          Sunrisers Hyderabad
# 634      Delhi          Sunrisers Hyderabad                Gujarat Lions
# 635  Bangalore          Sunrisers Hyderabad          Sunrisers Hyderabad
#
#                            team2
# 0    Royal Challengers Bangalore
# ...

# %%
d2['city'].value_counts()
# Out:
# Mumbai            85
# Bangalore         66
# Kolkata           61
# Delhi             60
# Hyderabad         49
# Chennai           48
# Chandigarh        46
# Jaipur            33
# Pune              32
# Durban            15
# Ahmedabad         12
# Centurion         12
# Visakhapatnam     11
# Rajkot            10
# Dharamsala         9
# Johannesburg       8
# Cape Town          7
# Abu Dhabi          7
# Ranchi             7
# Port Elizabeth     7
# Cuttack            7
# Raipur             6
# Sharjah            6
# Kochi              5
# Indore             5
# Kanpur             4
# Nagpur             3
# Kimberley          3
# East London        3
# Bloemfontein       2
# Name: city, dtype: int64

# %%
d2 = d2[d2['city']=='Mumbai']

# %%
d2
# Out:
#        city                   winner                        team1  \
# 6    Mumbai           Mumbai Indians        Kolkata Knight Riders
# 9    Mumbai           Mumbai Indians          Sunrisers Hyderabad
# 15   Mumbai           Mumbai Indians                Gujarat Lions
# 23   Mumbai           Mumbai Indians               Mumbai Indians
# 27   Mumbai   Rising Pune Supergiant       Rising Pune Supergiant
# ..      ...                      ...                          ...
# 572  Mumbai           Mumbai Indians               Mumbai Indians
# 576  Mumbai  Rising Pune Supergiants               Mumbai Indians
# 584  Mumbai            Gujarat Lions               Mumbai Indians
# 589  Mumbai           Mumbai Indians  Royal Challengers Bangalore
# 599  Mumbai           Mumbai Indians        Kolkata Knight Riders
#
#                        team2
# 6             Mumbai Indians
# 9             Mumbai Indians
# 15            Mumbai Indians
# 23          Delhi Daredevils
# ...

# %%
d3=d2[d2['team1']=="Mumbai Indians"]

# %%
d4=d2[d2['team2']=='Mumbai Indians']

# %%
fram=[d3,d3]
d5=pd.concat(fram)
d5
# Out:
#        city                       winner           team1  \
# 23   Mumbai               Mumbai Indians  Mumbai Indians
# 62   Mumbai  Royal Challengers Bangalore  Mumbai Indians
# 71   Mumbai              Deccan Chargers  Mumbai Indians
# 81   Mumbai               Mumbai Indians  Mumbai Indians
# 175  Mumbai               Mumbai Indians  Mumbai Indians
# ..      ...                          ...             ...
# 548  Mumbai               Mumbai Indians  Mumbai Indians
# 566  Mumbai               Mumbai Indians  Mumbai Indians
# 572  Mumbai               Mumbai Indians  Mumbai Indians
# 576  Mumbai      Rising Pune Supergiants  Mumbai Indians
# 584  Mumbai                Gujarat Lions  Mumbai Indians
#
#                            team2
# 23              Delhi Daredevils
# 62   Royal Challengers Bangalore
# 71               Deccan Chargers
# 81              Delhi Daredevils
# 175             Rajasthan Royals
# ..                           ...
# 548             Rajasthan Royals
# ...

# %%
d5['winner'].value_counts().plot(kind='bar')

# %%
d5['winner'].value_counts()
# Out:
# Mumbai Indians                 50
# Royal Challengers Bangalore     6
# Chennai Super Kings             6
# Deccan Chargers                 2
# Kochi Tuskers Kerala            2
# Rajasthan Royals                2
# Delhi Daredevils                2
# Kings XI Punjab                 2
# Rising Pune Supergiants         2
# Gujarat Lions                   2
# Name: winner, dtype: int64

# %%
#mumbai has won 50 out of 76 games played on mumbai

# %%
#calculating mumbai batting vs bowling on winning
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner  result  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore  normal
# 1       Rising Pune Supergiant       Rising Pune Supergiant  normal
# 2        Kolkata Knight Riders        Kolkata Knight Riders  normal
# 3              Kings XI Punjab              Kings XI Punjab  normal
# 4             Delhi Daredevils  Royal Challengers Bangalore  normal
#
#                         winner  win_by_runs  win_by_wickets player_of_match  \
# 0          Sunrisers Hyderabad           35               0    Yuvraj Singh
# ...

# %%
df_toss=df[["toss_winner","t_decision 1-bat 0-field"]]

# %%
df_toss
# Out:
#                      toss_winner  t_decision 1-bat 0-field
# 0    Royal Challengers Bangalore                         0
# 1         Rising Pune Supergiant                         0
# 2          Kolkata Knight Riders                         0
# 3                Kings XI Punjab                         0
# 4    Royal Challengers Bangalore                         1
# ..                           ...                       ...
# 631  Royal Challengers Bangalore                         0
# 632  Royal Challengers Bangalore                         0
# 633        Kolkata Knight Riders                         0
# 634          Sunrisers Hyderabad                         0
# 635          Sunrisers Hyderabad                         1
#
# [636 rows x 2 columns]

# %%
df_toss=df_toss[df_toss['toss_winner']=="Mumbai Indians"]

# %%
df_toss
# Out:
#         toss_winner  t_decision 1-bat 0-field
# 6    Mumbai Indians                         0
# 9    Mumbai Indians                         0
# 11   Mumbai Indians                         0
# 15   Mumbai Indians                         0
# 21   Mumbai Indians                         0
# ..              ...                       ...
# 599  Mumbai Indians                         0
# 604  Mumbai Indians                         0
# 612  Mumbai Indians                         0
# 616  Mumbai Indians                         0
# 618  Mumbai Indians                         1
#
# [85 rows x 2 columns]

# %%
df_toss['t_decision 1-bat 0-field'].value_counts()
# Out:
# 0    45
# 1    40
# Name: t_decision 1-bat 0-field, dtype: int64

# %%
# OUT OF 85 TIMES THEY HAVE WON TOSS THEY HAVE DECIDED TO BAT 40 TIMES AND FIELD 45 TIMES
df_yuvi=df[df['player_of_match']=='Yuvraj Singh']

# %%
df_yuvi['player_of_match'].value_counts()
# Out:
# Yuvraj Singh    5
# Name: player_of_match, dtype: int64

# %%
df['season'].value_counts().plot(kind='bar')

# %%
#max number of matches happend in 2013
#findindg how many matches mumbai won in 2013
df_2013=df[df['season']==2013]

# %%
df_2013=df_2013[df_2013['winner']=="Mumbai Indians"]

# %%
df_2013
# Out:
#       id  season     city        date                  team1  \
# 385  386    2013  Chennai  2013-04-06         Mumbai Indians
# 389  390    2013   Mumbai  2013-04-09         Mumbai Indians
# 394  395    2013   Mumbai  2013-04-13         Mumbai Indians
# 412  413    2013  Kolkata  2013-04-24  Kolkata Knight Riders
# 416  417    2013   Mumbai  2013-04-27         Mumbai Indians
# 420  421    2013   Mumbai  2013-04-29         Mumbai Indians
# 429  430    2013   Mumbai  2013-05-05         Mumbai Indians
# 433  434    2013   Mumbai  2013-05-07         Mumbai Indians
# 438  439    2013     Pune  2013-05-11          Pune Warriors
# 443  444    2013   Mumbai  2013-05-13    Sunrisers Hyderabad
# 446  447    2013   Mumbai  2013-05-15         Mumbai Indians
# 455  456    2013  Kolkata  2013-05-24       Rajasthan Royals
# 456  457    2013  Kolkata  2013-05-26         Mumbai Indians
#
#                            team2            toss_winner  result  \
# ...

# %%
df_2013.shape
# Out:
# (13, 17)

# %%
# MUMBAI INDIANS WON 13 MATCHES IN 2013

# %%
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner  result  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore  normal
# 1       Rising Pune Supergiant       Rising Pune Supergiant  normal
# 2        Kolkata Knight Riders        Kolkata Knight Riders  normal
# 3              Kings XI Punjab              Kings XI Punjab  normal
# 4             Delhi Daredevils  Royal Challengers Bangalore  normal
#
#                         winner  win_by_runs  win_by_wickets player_of_match  \
# 0          Sunrisers Hyderabad           35               0    Yuvraj Singh
# ...

# %%
sns.lineplot(x=df['season'],y=df['t_decision 1-bat 0-field'])

# %%
df['umpire3'].value_counts()
# Out:
# Series([], Name: umpire3, dtype: int64)

# %%
df.drop(columns=['umpire3'],inplace=True)

# %%
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner  result  \
# ...

# %%
# calculating mumbai win perentage outside mumbai
df2=df[df['city']!='Mumbai']

# %%
df2.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner  result  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore  normal
# 1       Rising Pune Supergiant       Rising Pune Supergiant  normal
# 2        Kolkata Knight Riders        Kolkata Knight Riders  normal
# 3              Kings XI Punjab              Kings XI Punjab  normal
# 4             Delhi Daredevils  Royal Challengers Bangalore  normal
#
#                         winner  win_by_runs  win_by_wickets player_of_match  \
# 0          Sunrisers Hyderabad           35               0    Yuvraj Singh
# ...

# %%
df2=df2[['team1','team2','winner']]

# %%
df2
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
df3=df2[df2['team1']=='Mumbai Indians']

# %%
df4=df2[df2['team2']=='Mumbai Indians']

# %%
df3.tail()
# Out:
#               team1                team2               winner
# 587  Mumbai Indians  Sunrisers Hyderabad  Sunrisers Hyderabad
# 596  Mumbai Indians      Kings XI Punjab       Mumbai Indians
# 618  Mumbai Indians      Kings XI Punjab      Kings XI Punjab
# 622  Mumbai Indians     Delhi Daredevils       Mumbai Indians
# 629  Mumbai Indians        Gujarat Lions        Gujarat Lions

# %%
frames=[df3,df4]
df5=pd.concat(frames)
df5
# Out:
#                            team1                   team2  \
# 1                 Mumbai Indians  Rising Pune Supergiant
# 43                Mumbai Indians        Delhi Daredevils
# 46                Mumbai Indians     Sunrisers Hyderabad
# 52                Mumbai Indians   Kolkata Knight Riders
# 58                Mumbai Indians  Rising Pune Supergiant
# ..                           ...                     ...
# 580        Kolkata Knight Riders          Mumbai Indians
# 592             Delhi Daredevils          Mumbai Indians
# 604      Rising Pune Supergiants          Mumbai Indians
# 612          Sunrisers Hyderabad          Mumbai Indians
# 616  Royal Challengers Bangalore          Mumbai Indians
#
#                      winner
# 1    Rising Pune Supergiant
# 43           Mumbai Indians
# 46      Sunrisers Hyderabad
# 52           Mumbai Indians
# 58           Mumbai Indians
# ..                      ...
# 580          Mumbai Indians
# 592        Delhi Daredevils
# ...

# %%
#SO MUMBAI HAS PLAYED 89 MATCHES OUTSIDE MUMBAI
df5['winner'].value_counts().plot(kind='bar')

# %%
df5['winner'].value_counts()
# Out:
# Mumbai Indians                 47
# Delhi Daredevils                8
# Chennai Super Kings             6
# Kings XI Punjab                 6
# Sunrisers Hyderabad             5
# Rajasthan Royals                5
# Royal Challengers Bangalore     4
# Kolkata Knight Riders           4
# Deccan Chargers                 2
# Rising Pune Supergiant          1
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %%
# OUT OF 89 MATCHES THEY WON 47 MATCHES OUTSIDE MUMBAI

# %%
# WE WILL  FIND HOW MANY MATCHES THE WIN AFTER WINNING TOSS
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner  result  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore  normal
# 1       Rising Pune Supergiant       Rising Pune Supergiant  normal
# 2        Kolkata Knight Riders        Kolkata Knight Riders  normal
# 3              Kings XI Punjab              Kings XI Punjab  normal
# 4             Delhi Daredevils  Royal Challengers Bangalore  normal
#
#                         winner  win_by_runs  win_by_wickets player_of_match  \
# 0          Sunrisers Hyderabad           35               0    Yuvraj Singh
# ...

# %%
df2=df[df['toss_winner']=='Mumbai Indians']

# %%
df2
# Out:
#       id  season           city        date                        team1  \
# 6      7    2017         Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017         Mumbai  2017-04-12          Sunrisers Hyderabad
# 11    12    2017      Bangalore  2017-04-14  Royal Challengers Bangalore
# 15    16    2017         Mumbai  2017-04-16                Gujarat Lions
# 21    22    2017         Indore  2017-04-20              Kings XI Punjab
# ..   ...     ...            ...         ...                          ...
# 599  600    2016         Mumbai  2016-04-28        Kolkata Knight Riders
# 604  605    2016           Pune  2016-05-01      Rising Pune Supergiants
# 612  613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 616  617    2016      Bangalore  2016-05-11  Royal Challengers Bangalore
# 618  619    2016  Visakhapatnam  2016-05-13               Mumbai Indians
#
#                team2     toss_winner  result               winner  \
# ...

# %%
df2['winner'].value_counts()
# Out:
# Mumbai Indians                 48
# Kings XI Punjab                 9
# Delhi Daredevils                6
# Royal Challengers Bangalore     5
# Chennai Super Kings             5
# Sunrisers Hyderabad             4
# Rising Pune Supergiant          2
# Kolkata Knight Riders           2
# Rajasthan Royals                2
# Pune Warriors                   1
# Rising Pune Supergiants         1
# Name: winner, dtype: int64

# %%
# OUT OF 85 TIMES THEY WON TOSS 48 TIMES THEY HAVE WON THE MATCH
